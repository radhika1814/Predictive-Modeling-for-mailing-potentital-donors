# %% [markdown]
# # Solution and code for question 1 and 2

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from pandas import DataFrame
import matplotlib
# %matplotlib inline

# %%
dataset = pd.read_csv('C:/Users/HP/Desktop/SampleDonorData.csv')

# %%
dataset.hist(column='DONOR_AGE')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000009C5C61B780>]],
#       dtype=object)

# %%
datasetcont=dataset.drop(dataset.columns[[6,8,9,18]], axis=1)
#'URBANICITY','HOME_OWNER','DONOR_GENDER','recency_freq_status'

# %% [markdown]
# We can see different summary statistics the mean, standard deviation, median would be the 50% value

# %% [markdown]
# Summary statistics for all the variables in the data. 1b.

# %%
dataset.describe()
# Out:
#            TARGET_B      TARGET_D  CONTROL_NUMBER  MONTHS_SINCE_ORIGIN  \
# count  19372.000000  19372.000000    19372.000000         19372.000000
# mean       0.250000      3.906463    96546.225377            73.409973
# std        0.433024      9.192082    55830.643871            41.255574
# min        0.000000      0.000000        5.000000             5.000000
# 25%        0.000000      0.000000    48289.000000            29.000000
# 50%        0.000000      0.000000    96937.000000            65.000000
# 75%        0.250000      0.250000   145429.500000           113.000000
# max        1.000000    200.000000   191779.000000           137.000000
#
#           DONOR_AGE      IN_HOUSE  CLUSTER_CODE  INCOME_GROUP  \
# count  14577.000000  19372.000000  18918.000000  14980.000000
# mean      58.919051      0.073198     27.861613      3.907543
# std       16.669382      0.260469     14.451392      1.864796
# min        0.000000      0.000000      1.000000      1.000000
# 25%       47.000000      0.000000     15.000000      2.000000
# 50%       60.000000      0.000000     28.000000      4.000000
# 75%       73.000000      0.000000     40.000000      5.000000
# max       87.000000      1.000000     53.000000      7.000000
#
#        PUBLISHED_PHONE  WEALTH_RATING           ...             \
# count     19372.000000   10562.000000           ...
# mean          0.497729       5.005397           ...
# std           0.500008       2.815386           ...
# min           0.000000       0.000000           ...
# 25%           0.000000       3.000000           ...
# 50%           0.000000       5.000000           ...
# 75%           1.000000       7.000000           ...
# max           1.000000       9.000000           ...
#
#        MEDIAN_HOUSEHOLD_INCOME  PCT_OWNER_OCCUPIED      PEP_STAR  \
# count             19372.000000        19372.000000  19372.000000
# mean                341.970215           69.698999      0.504439
# std                 164.207807           21.711019      0.499993
# min                   0.000000            0.000000      0.000000
# 25%                 232.000000           60.000000      0.000000
# 50%                 311.000000           76.000000      1.000000
# 75%                 417.000000           85.000000      1.000000
# max                1500.000000           99.000000      1.000000
#
#        RECENT_STAR_STATUS  RECENT_CARD_RESPONSE_PROP  \
# count        19372.000000               19372.000000
# mean             0.221402                   0.230808
# std              0.415201                   0.186230
# min              0.000000                   0.000000
# 25%              0.000000                   0.100000
# 50%              0.000000                   0.200000
# 75%              0.000000                   0.333000
# max              1.000000                   1.000000
#
#        MONTHS_SINCE_LAST_PROM_RESP  LAST_GIFT_AMT  NUMBER_PROM_12  \
# count                 19126.000000   19372.000000    19372.000000
# mean                     19.038900      16.584503       12.901869
# std                       3.415559      11.977709        4.642072
# min                     -12.000000       0.000000        2.000000
# 25%                      17.000000      10.000000       11.000000
# 50%                      18.000000      15.000000       12.000000
# 75%                      21.000000      20.000000       13.000000
# max                      36.000000     450.000000       64.000000
#
#        MONTHS_SINCE_LAST_GIFT  MONTHS_SINCE_FIRST_GIFT
# count            19372.000000             19372.000000
# mean                18.191152                69.482088
# std                  4.033065                37.568169
# min                  4.000000                15.000000
# 25%                 16.000000                33.000000
# 50%                 18.000000                65.000000
# 75%                 20.000000               105.000000
# max                 27.000000               260.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# Correlation plot for continour variables

# %%
import seaborn as sns
corr = datasetcont.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
